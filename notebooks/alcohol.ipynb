# %%
import pandas as pd

# %%
pd.read_csv("https://chronicdata.cdc.gov/api/views/yqqr-a7uy/rows.csv?accessType=DOWNLOAD&bom=true&format=true")
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 0            2006     2010           ID        Idaho       ARDI
# 1            2006     2010           KY     Kentucky       ARDI
# 2            2006     2010           WI    Wisconsin       ARDI
# 3            2006     2010           MN    Minnesota       ARDI
# 4            2006     2010           IL     Illinois       ARDI
# ...           ...      ...          ...          ...        ...
# 106231       2006     2010           HI       Hawaii       ARDI
# 106232       2006     2010           CT  Connecticut       ARDI
# 106233       2006     2010           CA   California       ARDI
# 106234       2006     2010           NV       Nevada       ARDI
# 106235       2006     2010           VA     Virginia       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 0           Excessive Use     Harmful Effects    Chronic
# 1           Excessive Use     Harmful Effects    Acute
# ...

# %%
alcohol_1 = pd.read_csv("https://chronicdata.cdc.gov/api/views/yqqr-a7uy/rows.csv?accessType=DOWNLOAD&bom=true&format=true")

# %%
alcohol_1.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource ConsumptionPattern  \
# 0       2006     2010           ID        Idaho       ARDI      Excessive Use
# 1       2006     2010           KY     Kentucky       ARDI      Excessive Use
# 2       2006     2010           WI    Wisconsin       ARDI      Excessive Use
# 3       2006     2010           MN    Minnesota       ARDI      Excessive Use
# 4       2006     2010           IL     Illinois       ARDI      Excessive Use
#
#             Effect ConditionType                      Condition     Sex  ...  \
# 0  Harmful Effects    Chronic              Oropharyngeal cancer    Male  ...
# 1  Harmful Effects    Acute                    Firearm injuries  Female  ...
# 2  Harmful Effects    Chronic               Stroke, hemorrhagic    Male  ...
# 3  Harmful Effects    Acute       Motor-vehicle traffic crashes  Female  ...
# 4  Harmful Effects    Chronic                  Laryngeal cancer    Male  ...
#
# ...

# %%
alcohol_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106236 entries, 0 to 106235
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   YearStart           106236 non-null  int64
#  1   YearEnd             106236 non-null  int64
#  2   LocationAbbr        106236 non-null  object
#  3   LocationDesc        106236 non-null  object
#  4   DataSource          106236 non-null  object
#  5   ConsumptionPattern  106236 non-null  object
#  6   Effect              106236 non-null  object
#  7   ConditionType       106236 non-null  object
#  8   Condition           106236 non-null  object
#  9   Sex                 106236 non-null  object
#  10  AgeCategory         106236 non-null  object
#  11  AgeGroup            106236 non-null  object
#  12  Data_Value_Unit     106236 non-null  object
#  13  Data_Value_Type     106236 non-null  object
#  14  Data_Value          106236 non-null  object
# ...

# %%
alcohol_1.Condition
# Out:
# 0                      Oropharyngeal cancer
# 1                          Firearm injuries
# 2                       Stroke, hemorrhagic
# 3             Motor-vehicle traffic crashes
# 4                          Laryngeal cancer
#                         ...
# 106231                         Hypertension
# 106232                            Psoriasis
# 106233                  Air-space transport
# 106234    Occupational and machine injuries
# 106235                  Alcoholic gastritis
# Name: Condition, Length: 106236, dtype: object

# %%
alcohol_1.dtypes
# Out:
# YearStart              int64
# YearEnd                int64
# LocationAbbr          object
# LocationDesc          object
# DataSource            object
# ConsumptionPattern    object
# Effect                object
# ConditionType         object
# Condition             object
# Sex                   object
# AgeCategory           object
# AgeGroup              object
# Data_Value_Unit       object
# Data_Value_Type       object
# Data_Value            object
# Data_Value_Alt        object
# LocationID             int64
# ClassID               object
# EffectID              object
# ConditionID           object
# ConsumptionID         object
# Stratification1ID     object
# AgeCategoryID         object
# Stratification2ID     object
# DataValueTypeID       object
# dtype: object

# %%
alcohol_1['Data_Value_Alt'] = alcohol_1['Data_Value_Alt'].str.replace(r',', '').astype(str)

# %%
type(alcohol_1['Data_Value_Alt'][0])
# Out:
# str

# %%
alcohol_1['Data_Value_Alt']=alcohol_1['Data_Value_Alt'].astype(float)

# %%
type(alcohol_1['Data_Value_Alt'][0])
# Out:
# numpy.float64

# %%
alcohol_1.sort_values("Data_Value_Alt", ascending = False)
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 51493        2006     2010           US     National       ARDI
# 85688        2006     2010           US     National       ARDI
# 20061        2006     2010           US     National       ARDI
# 70651        2006     2010           US     National       ARDI
# 105337       2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 43862        2006     2010           US     National       ARDI
# 71926        2006     2010           US     National       ARDI
# 101044       2006     2010           US     National       ARDI
# 31095        2006     2010           US     National       ARDI
# 58995        2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 51493       Excessive Use     Harmful Effects    All causes
# 85688       Excessive Use     Harmful Effects    All causes
# ...

# %%
alcohol_1.LocationAbbr.value_counts()
# Out:
# US    2364
# CA    2316
# FL    2214
# NY    2208
# CO    2178
# TX    2166
# OH    2166
# GA    2160
# PA    2148
# IL    2130
# NC    2130
# AZ    2124
# IN    2118
# KY    2118
# MA    2112
# VA    2106
# MI    2100
# OR    2094
# MN    2094
# AR    2094
# SC    2082
# MD    2070
# LA    2070
# AL    2070
# NJ    2070
# OK    2064
# WV    2058
# WA    2058
# IA    2046
# MO    2046
# TN    2046
# NM    2046
# WI    2022
# MT    2022
# CT    2004
# MS    1980
# KS    1980
# ID    1962
# NE    1956
# NV    1956
# UT    1932
# ME    1932
# HI    1920
# WY    1908
# SD    1902
# AK    1896
# NH    1890
# ND    1878
# RI    1860
# DE    1848
# DC    1764
# VT    1758
# Name: LocationAbbr, dtype: int64

# %%
national = 'US'

# %%
alcohol_1[alcohol_1.LocationAbbr == national]
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 251          2006     2010           US     National       ARDI
# 289          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 105844       2006     2010           US     National       ARDI
# 105872       2006     2010           US     National       ARDI
# 105873       2006     2010           US     National       ARDI
# 106093       2006     2010           US     National       ARDI
# 106142       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol = alcohol_1[alcohol_1.LocationAbbr == national]

# %%
national_alcohol
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 251          2006     2010           US     National       ARDI
# 289          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 105844       2006     2010           US     National       ARDI
# 105872       2006     2010           US     National       ARDI
# 105873       2006     2010           US     National       ARDI
# 106093       2006     2010           US     National       ARDI
# 106142       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol.sort_values("Data_Value_Alt", ascending = False)
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 51493        2006     2010           US     National       ARDI
# 85688        2006     2010           US     National       ARDI
# 20061        2006     2010           US     National       ARDI
# 70651        2006     2010           US     National       ARDI
# 105337       2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 43862        2006     2010           US     National       ARDI
# 35150        2006     2010           US     National       ARDI
# 58995        2006     2010           US     National       ARDI
# 101044       2006     2010           US     National       ARDI
# 31095        2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 51493       Excessive Use     Harmful Effects    All causes
# 85688       Excessive Use     Harmful Effects    All causes
# ...

# %%
national_alcohol.AgeGroup.value_counts()
# Out:
# 35-49       342
# All Ages    342
# 50-64       342
# 20-34       342
# 65+         342
# 0-19        342
# 0-<21       312
# Name: AgeGroup, dtype: int64

# %%
allages = 'All Ages'

# %%
national_alcohol[national_alcohol.AgeGroup == allages]
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 251          2006     2010           US     National       ARDI
# 289          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 101801       2006     2010           US     National       ARDI
# 102793       2006     2010           US     National       ARDI
# 104450       2006     2010           US     National       ARDI
# 105139       2006     2010           US     National       ARDI
# 105337       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol1 = national_alcohol[national_alcohol.AgeGroup == allages]

# %%
national_alcohol1
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 251          2006     2010           US     National       ARDI
# 289          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 101801       2006     2010           US     National       ARDI
# 102793       2006     2010           US     National       ARDI
# 104450       2006     2010           US     National       ARDI
# 105139       2006     2010           US     National       ARDI
# 105337       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol1.sort_values("Data_Value_Alt", ascending = False)
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 51493        2006     2010           US     National       ARDI
# 85688        2006     2010           US     National       ARDI
# 20061        2006     2010           US     National       ARDI
# 70651        2006     2010           US     National       ARDI
# 105337       2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 94380        2006     2010           US     National       ARDI
# 447          2006     2010           US     National       ARDI
# 101044       2006     2010           US     National       ARDI
# 58995        2006     2010           US     National       ARDI
# 31095        2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 51493       Excessive Use     Harmful Effects    All causes
# 85688       Excessive Use     Harmful Effects    All causes
# ...

# %%
national_alcohol1[national_alcohol1.Condition != 'Total for all causes']
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 251          2006     2010           US     National       ARDI
# 289          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 101733       2006     2010           US     National       ARDI
# 101801       2006     2010           US     National       ARDI
# 102793       2006     2010           US     National       ARDI
# 105139       2006     2010           US     National       ARDI
# 105337       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol2 = national_alcohol1[national_alcohol1.Condition != 'Total for all causes']

# %%
national_alcohol2.sort_values("Data_Value_Alt", ascending = False)
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 20061        2006     2010           US     National       ARDI
# 70651        2006     2010           US     National       ARDI
# 105337       2006     2010           US     National       ARDI
# 92895        2006     2010           US     National       ARDI
# 31838        2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 1256         2006     2010           US     National       ARDI
# 447          2006     2010           US     National       ARDI
# 94380        2006     2010           US     National       ARDI
# 101044       2006     2010           US     National       ARDI
# 31095        2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 20061       Excessive Use     Harmful Effects    Acute
# 70651       Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol2[national_alcohol2.Condition != 'Subtotal all causes']
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 251          2006     2010           US     National       ARDI
# 289          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 101589       2006     2010           US     National       ARDI
# 101733       2006     2010           US     National       ARDI
# 101801       2006     2010           US     National       ARDI
# 102793       2006     2010           US     National       ARDI
# 105139       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol3= national_alcohol2[national_alcohol2.Condition != 'Subtotal all causes']

# %%
national_alcohol3
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 251          2006     2010           US     National       ARDI
# 289          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 101589       2006     2010           US     National       ARDI
# 101733       2006     2010           US     National       ARDI
# 101801       2006     2010           US     National       ARDI
# 102793       2006     2010           US     National       ARDI
# 105139       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol3.sort_values("Data_Value_Alt", ascending = False)
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 31838        2006     2010           US     National       ARDI
# 43054        2006     2010           US     National       ARDI
# 2792         2006     2010           US     National       ARDI
# 2115         2006     2010           US     National       ARDI
# 29687        2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 46996        2006     2010           US     National       ARDI
# 105139       2006     2010           US     National       ARDI
# 1256         2006     2010           US     National       ARDI
# 447          2006     2010           US     National       ARDI
# 31095        2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 31838       Excessive Use     Harmful Effects    Chronic
# 43054       Excessive Use     Harmful Effects    Acute
# ...

# %%
national_alcohol3.Sex.value_counts()
# Out:
# Female     108
# Male       108
# Overall    108
# Name: Sex, dtype: int64

# %%
overall = 'Overall'

# %%
national_alcohol3[national_alcohol3.Sex == overall]
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 6937         2006     2010           US     National       ARDI
# 7469         2006     2010           US     National       ARDI
# 7622         2006     2010           US     National       ARDI
# 8142         2006     2010           US     National       ARDI
# 8582         2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 100141       2006     2010           US     National       ARDI
# 100999       2006     2010           US     National       ARDI
# 101151       2006     2010           US     National       ARDI
# 101589       2006     2010           US     National       ARDI
# 101801       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 6937        Excessive Use     Harmful Effects    Acute
# 7469        Excessive Use  Beneficial Effects    Chronic
# ...

# %%
national_alcohol4 = national_alcohol3[national_alcohol3.Sex == overall]

# %%
national_alcohol4
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 6937         2006     2010           US     National       ARDI
# 7469         2006     2010           US     National       ARDI
# 7622         2006     2010           US     National       ARDI
# 8142         2006     2010           US     National       ARDI
# 8582         2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 100141       2006     2010           US     National       ARDI
# 100999       2006     2010           US     National       ARDI
# 101151       2006     2010           US     National       ARDI
# 101589       2006     2010           US     National       ARDI
# 101801       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 6937        Excessive Use     Harmful Effects    Acute
# 7469        Excessive Use  Beneficial Effects    Chronic
# ...

# %%
national_alcohol4.sort_values("Data_Value_Alt", ascending = False)
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  ...  \
# 31838        2006     2010           US     National       ARDI  ...
# 43054        2006     2010           US     National       ARDI  ...
# 29687        2006     2010           US     National       ARDI  ...
# 23368        2006     2010           US     National       ARDI  ...
# 29950        2006     2010           US     National       ARDI  ...
# ...           ...      ...          ...          ...        ...  ...
# 72565        2006     2010           US     National       ARDI  ...
# 72949        2006     2010           US     National       ARDI  ...
# 74339        2006     2010           US     National       ARDI  ...
# 101801       2006     2010           US     National       ARDI  ...
# 31095        2006     2010           US     National       ARDI  ...
#
#        ConsumptionID Stratification1ID AgeCategoryID Stratification2ID  \
# ...

# %%
national_alcohol4.to_csv("toptotal.csv")

# %%
national_alcohol3
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 251          2006     2010           US     National       ARDI
# 289          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 101589       2006     2010           US     National       ARDI
# 101733       2006     2010           US     National       ARDI
# 101801       2006     2010           US     National       ARDI
# 102793       2006     2010           US     National       ARDI
# 105139       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol3.Sex.value_counts()
# Out:
# Female     108
# Male       108
# Overall    108
# Name: Sex, dtype: int64

# %%
ladies = 'Female'

# %%
national_alcohol3[national_alcohol3.Sex == ladies]
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# 426          2006     2010           US     National       ARDI
# 510          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 97217        2006     2010           US     National       ARDI
# 98291        2006     2010           US     National       ARDI
# 99279        2006     2010           US     National       ARDI
# 99380        2006     2010           US     National       ARDI
# 101733       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol5 = national_alcohol3[national_alcohol3.Sex == ladies]

# %%
national_alcohol5
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 153          2006     2010           US     National       ARDI
# 250          2006     2010           US     National       ARDI
# 373          2006     2010           US     National       ARDI
# 426          2006     2010           US     National       ARDI
# 510          2006     2010           US     National       ARDI
# ...           ...      ...          ...          ...        ...
# 97217        2006     2010           US     National       ARDI
# 98291        2006     2010           US     National       ARDI
# 99279        2006     2010           US     National       ARDI
# 99380        2006     2010           US     National       ARDI
# 101733       2006     2010           US     National       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 153         Excessive Use     Harmful Effects    Chronic
# 250         Excessive Use     Harmful Effects    Chronic
# ...

# %%
national_alcohol5.sort_values("Data_Value_Alt", ascending = False)
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  ...  \
# 2508         2006     2010           US     National       ARDI  ...
# 1526         2006     2010           US     National       ARDI  ...
# 1710         2006     2010           US     National       ARDI  ...
# 1052         2006     2010           US     National       ARDI  ...
# 917          2006     2010           US     National       ARDI  ...
# ...           ...      ...          ...          ...        ...  ...
# 46776        2006     2010           US     National       ARDI  ...
# 47131        2006     2010           US     National       ARDI  ...
# 50019        2006     2010           US     National       ARDI  ...
# 101733       2006     2010           US     National       ARDI  ...
# 1256         2006     2010           US     National       ARDI  ...
#
#        ConsumptionID Stratification1ID AgeCategoryID Stratification2ID  \
# ...

# %%
alcohol_1
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 0            2006     2010           ID        Idaho       ARDI
# 1            2006     2010           KY     Kentucky       ARDI
# 2            2006     2010           WI    Wisconsin       ARDI
# 3            2006     2010           MN    Minnesota       ARDI
# 4            2006     2010           IL     Illinois       ARDI
# ...           ...      ...          ...          ...        ...
# 106231       2006     2010           HI       Hawaii       ARDI
# 106232       2006     2010           CT  Connecticut       ARDI
# 106233       2006     2010           CA   California       ARDI
# 106234       2006     2010           NV       Nevada       ARDI
# 106235       2006     2010           VA     Virginia       ARDI
#
#        ConsumptionPattern              Effect ConditionType  \
# 0           Excessive Use     Harmful Effects    Chronic
# 1           Excessive Use     Harmful Effects    Acute
# ...

# %%
alcohol_1.Effect.value_counts()
# Out:
# Harmful Effects       53118
# Beneficial Effects    53118
# Name: Effect, dtype: int64

# %%
alcohol_1.Sex.value_counts()
# Out:
# Overall    35412
# Female     35412
# Male       35412
# Name: Sex, dtype: int64

# %%
alcohol_1.AgeGroup.value_counts()
# Out:
# 20-34       16122
# All Ages    16122
# 35-49       16122
# 65+         16122
# 0-19        16122
# 50-64       16122
# 0-<21        9504
# Name: AgeGroup, dtype: int64

# %%
harm= 'Harmful Effects'
genders= 'Overall'
allages2= 'All Ages'

# %%
alcohol_1[alcohol_1.Effect == harm]
# Out:
#         YearStart  YearEnd LocationAbbr  LocationDesc DataSource  \
# 0            2006     2010           ID         Idaho       ARDI
# 1            2006     2010           KY      Kentucky       ARDI
# 2            2006     2010           WI     Wisconsin       ARDI
# 3            2006     2010           MN     Minnesota       ARDI
# 4            2006     2010           IL      Illinois       ARDI
# ...           ...      ...          ...           ...        ...
# 106228       2006     2010           ME         Maine       ARDI
# 106229       2006     2010           PA  Pennsylvania       ARDI
# 106231       2006     2010           HI        Hawaii       ARDI
# 106234       2006     2010           NV        Nevada       ARDI
# 106235       2006     2010           VA      Virginia       ARDI
#
#        ConsumptionPattern           Effect ConditionType  \
# 0           Excessive Use  Harmful Effects    Chronic
# 1           Excessive Use  Harmful Effects    Acute
# ...

# %%
alc_suicide1= alcohol_1[alcohol_1.Effect == harm]

# %%
alc_suicide1
# Out:
#         YearStart  YearEnd LocationAbbr  LocationDesc DataSource  \
# 0            2006     2010           ID         Idaho       ARDI
# 1            2006     2010           KY      Kentucky       ARDI
# 2            2006     2010           WI     Wisconsin       ARDI
# 3            2006     2010           MN     Minnesota       ARDI
# 4            2006     2010           IL      Illinois       ARDI
# ...           ...      ...          ...           ...        ...
# 106228       2006     2010           ME         Maine       ARDI
# 106229       2006     2010           PA  Pennsylvania       ARDI
# 106231       2006     2010           HI        Hawaii       ARDI
# 106234       2006     2010           NV        Nevada       ARDI
# 106235       2006     2010           VA      Virginia       ARDI
#
#        ConsumptionPattern           Effect ConditionType  \
# 0           Excessive Use  Harmful Effects    Chronic
# 1           Excessive Use  Harmful Effects    Acute
# ...

# %%
alc_suicide1[alc_suicide1.Sex == genders]
# Out:
#         YearStart  YearEnd LocationAbbr  LocationDesc DataSource  \
# 3611         2006     2010           IL      Illinois       ARDI
# 3618         2006     2010           MT       Montana       ARDI
# 3622         2006     2010           NY      New York       ARDI
# 3629         2006     2010           IL      Illinois       ARDI
# 3630         2006     2010           CO      Colorado       ARDI
# ...           ...      ...          ...           ...        ...
# 106196       2006     2010           KS        Kansas       ARDI
# 106205       2006     2010           ME         Maine       ARDI
# 106222       2006     2010           OR        Oregon       ARDI
# 106229       2006     2010           PA  Pennsylvania       ARDI
# 106234       2006     2010           NV        Nevada       ARDI
#
#        ConsumptionPattern           Effect ConditionType  \
# 3611        Excessive Use  Harmful Effects    Acute
# 3618        Excessive Use  Harmful Effects    Acute
# ...

# %%
alc_suicide2= alc_suicide1[alc_suicide1.Sex == genders]

# %%
alc_suicide2
# Out:
#         YearStart  YearEnd LocationAbbr  LocationDesc DataSource  \
# 3611         2006     2010           IL      Illinois       ARDI
# 3618         2006     2010           MT       Montana       ARDI
# 3622         2006     2010           NY      New York       ARDI
# 3629         2006     2010           IL      Illinois       ARDI
# 3630         2006     2010           CO      Colorado       ARDI
# ...           ...      ...          ...           ...        ...
# 106196       2006     2010           KS        Kansas       ARDI
# 106205       2006     2010           ME         Maine       ARDI
# 106222       2006     2010           OR        Oregon       ARDI
# 106229       2006     2010           PA  Pennsylvania       ARDI
# 106234       2006     2010           NV        Nevada       ARDI
#
#        ConsumptionPattern           Effect ConditionType  \
# 3611        Excessive Use  Harmful Effects    Acute
# 3618        Excessive Use  Harmful Effects    Acute
# ...

# %%
alc_suicide2[alc_suicide2.AgeGroup == allages2]
# Out:
#         YearStart  YearEnd LocationAbbr  LocationDesc DataSource  \
# 3682         2006     2010           ID         Idaho       ARDI
# 3692         2006     2010           AL       Alabama       ARDI
# 3737         2006     2010           VT       Vermont       ARDI
# 3754         2006     2010           MO      Missouri       ARDI
# 3776         2006     2010           WA    Washington       ARDI
# ...           ...      ...          ...           ...        ...
# 106020       2006     2010           OH          Ohio       ARDI
# 106122       2006     2010           IA          Iowa       ARDI
# 106167       2006     2010           RI  Rhode Island       ARDI
# 106189       2006     2010           ME         Maine       ARDI
# 106234       2006     2010           NV        Nevada       ARDI
#
#        ConsumptionPattern           Effect ConditionType  \
# 3682        Excessive Use  Harmful Effects    Acute
# 3692        Excessive Use  Harmful Effects    Chronic
# ...

# %%
alc_suicide3= alc_suicide2[alc_suicide2.AgeGroup == allages2]

# %%
alc_suicide3
# Out:
#         YearStart  YearEnd LocationAbbr  LocationDesc DataSource  \
# 3682         2006     2010           ID         Idaho       ARDI
# 3692         2006     2010           AL       Alabama       ARDI
# 3737         2006     2010           VT       Vermont       ARDI
# 3754         2006     2010           MO      Missouri       ARDI
# 3776         2006     2010           WA    Washington       ARDI
# ...           ...      ...          ...           ...        ...
# 106020       2006     2010           OH          Ohio       ARDI
# 106122       2006     2010           IA          Iowa       ARDI
# 106167       2006     2010           RI  Rhode Island       ARDI
# 106189       2006     2010           ME         Maine       ARDI
# 106234       2006     2010           NV        Nevada       ARDI
#
#        ConsumptionPattern           Effect ConditionType  \
# 3682        Excessive Use  Harmful Effects    Acute
# 3692        Excessive Use  Harmful Effects    Chronic
# ...

# %%
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 51493       2006     2010           US     National       ARDI
# 20061       2006     2010           US     National       ARDI
# 70651       2006     2010           US     National       ARDI
# 31838       2006     2010           US     National       ARDI
# 43054       2006     2010           US     National       ARDI
# ...          ...      ...          ...          ...        ...
# 39842       2006     2010           MT      Montana       ARDI
# 39924       2006     2010           NJ   New Jersey       ARDI
# 39976       2006     2010           IA         Iowa       ARDI
# 63000       2006     2010           UT         Utah       ARDI
# 91198       2006     2010           DE     Delaware       ARDI
#
#       ConsumptionPattern           Effect ConditionType  \
# 51493      Excessive Use  Harmful Effects    All causes
# 20061      Excessive Use  Harmful Effects    Acute
# ...

# %%
alc_suicide3.Condition.value_counts()
# Out:
# Subtotal all causes                                      104
# Oropharyngeal cancer                                      52
# Epilepsy                                                  52
# Homicide                                                  52
# Cholelithiases                                            52
# Alcohol abuse                                             52
# Fire injuries                                             52
# Occupational and machine injuries                         52
# Suicide                                                   52
# Stroke, ischemic                                          52
# Ischemic heart disease                                    52
# Motor-vehicle nontraffic crashes                          52
# Drowning                                                  52
# Alcoholic psychosis                                       52
# Air-space transport                                       52
# ...

# %%
suicide= "Suicide"

# %%
alc_suicide3[alc_suicide3.Condition == suicide]
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 8802         2006     2010           WI             Wisconsin       ARDI
# 9868         2006     2010           ND          North Dakota       ARDI
# 9880         2006     2010           LA             Louisiana       ARDI
# 14228        2006     2010           MI              Michigan       ARDI
# 17572        2006     2010           SC        South Carolina       ARDI
# 17750        2006     2010           UT                  Utah       ARDI
# 23368        2006     2010           US              National       ARDI
# 23698        2006     2010           CT           Connecticut       ARDI
# 26563        2006     2010           DE              Delaware       ARDI
# 27508        2006     2010           ME                 Maine       ARDI
# 32465        2006     2010           KY              Kentucky       ARDI
# 33812        2006     2010           RI          Rhode Island       ARDI
# ...

# %%
alc_suicide4 = alc_suicide3[alc_suicide3.Condition == suicide]

# %%
alc_suicide4
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 8802         2006     2010           WI             Wisconsin       ARDI
# 9868         2006     2010           ND          North Dakota       ARDI
# 9880         2006     2010           LA             Louisiana       ARDI
# 14228        2006     2010           MI              Michigan       ARDI
# 17572        2006     2010           SC        South Carolina       ARDI
# 17750        2006     2010           UT                  Utah       ARDI
# 23368        2006     2010           US              National       ARDI
# 23698        2006     2010           CT           Connecticut       ARDI
# 26563        2006     2010           DE              Delaware       ARDI
# 27508        2006     2010           ME                 Maine       ARDI
# 32465        2006     2010           KY              Kentucky       ARDI
# 33812        2006     2010           RI          Rhode Island       ARDI
# ...

# %%
alc_suicide4.sort_values("Data_Value_Alt", ascending = False)
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 23368        2006     2010           US              National       ARDI
# 76703        2006     2010           CA            California       ARDI
# 64369        2006     2010           FL               Florida       ARDI
# 103585       2006     2010           TX                 Texas       ARDI
# 82383        2006     2010           PA          Pennsylvania       ARDI
# 65706        2006     2010           NY              New York       ARDI
# 48798        2006     2010           OH                  Ohio       ARDI
# 14228        2006     2010           MI              Michigan       ARDI
# 102308       2006     2010           NC        North Carolina       ARDI
# 61824        2006     2010           IL              Illinois       ARDI
# 63964        2006     2010           GA               Georgia       ARDI
# 104713       2006     2010           AZ               Arizona       ARDI
# ...

# %%
alc_suicide4.to_csv("alc_suicide_states.csv")

# %%
pd.read_csv(Users/theresagaff/Documents/cuny-data/project-alcohol/data/state-pops.csv)
# Out:
#   File "<ipython-input-145-7a2516d92c0d>", line 1
#     pd.read_csv(r'Users/theresagaff/Documents/cuny-data/project-alcohol/data/state-pops.csv)
#                                                                                             ^
# SyntaxError: EOL while scanning string literal
